# %% [markdown]
# ## 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
#     Competition I chosed: https://www.kaggle.com/c/digit-recognizer (手寫數字辨識)
#
# 1. 你選的這組資料為何重要?
#
#   Ans:公眾利利益 / 影響政策⽅方向(可將一些紙本資料電子化，更容易保存及查找使用)
#
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)?
#
#   Ans: MNIST database. It was created by "re-mixing" the samples from NIST's original datasets. The creators felt that since NIST's training dataset was taken from American Census Bureau employees, while the testing dataset was taken from American high school students it was not well-suited for machine learning experiments. Furthermore, the black and white images from NIST were normalized to fit into a 28x28 pixel bounding box and anti-aliased, which introduced grayscale levels.
#
#
# 3. 蒐集而來的資料型態為何?
#
#   Ans:非結構化資料(需要思考資料轉換與標準化⽅方式),圖像。
#
#
# 4. 這組資料想解決的問題如何評估?
#
#   Ans: error rate(or correct rate) in percentage

# %% [markdown]
# ## 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#   Ans: 提升業績：增加訂單量?調整價格?
#   假設：在其他現有條件不做更動的前提下，透過動態的價格調整讓訂單量或總營業額增加
#
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐
#
#   Ans:需要的資料：每筆交易的金額、時間和其他細節(乘客人數?車子的最大乘坐人數?車種?)
#   資料蒐集：請顧客填寫問卷? 叫車需辦會員?
#
#
# 3. 蒐集而來的資料型態為何?
#
#   Ans:結構化資料(表格，欄位值型態包含數字、字串)
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#   Ans:系統要能給出最適合當下的價格，讓整體利益最大化。

# %% [markdown]
# ## 作業3
#
#
# 依照 Day_001_example_of_metrics.ipynb,仿造範例的MAE函數, 自己寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    return sum((y - yp)**2) / len(y)

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 274.067
# The Mean absolute error is 13.109
